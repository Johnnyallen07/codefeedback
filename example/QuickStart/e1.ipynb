# %% [markdown]
# # Quick Start:
#
# Load all extensions at first including: load extensions, answers, and necessary external modules:

# %%
# %load_ext codefeedback
# %load ans.py
# Out:
# Successfully loaded the extension
# Successfully loaded solutions from: ans.py

# %% [markdown]
# ## The format of answer:
#
# The answer in py script should only be: solution = {task_name: (check_list, solution_codes, configs)}

# %%
# %load ans.py
# Out:
# Successfully loaded solutions from: ans.py

# %%
import numpy as np
import random
# %load_module
# Out:
# Successfully loaded required modules

# %% [markdown]
# Alternatively, we can use: `codefeedback.load_module()`

# %%
import codefeedback
codefeedback.load_module("import numpy as np\nimport random")
# Out:
# Successfully loaded required modules

# %% [markdown]
# Check the following codes with structure check and without structure check:

# %%
print(2)
# %check e1
# Out:
# 2
# <p style="color:green;">Your code is correct.</p>

# %%
print(2)
# %check e2
# Out:
# 2
# <p style="color:red;">Check your code, it's not correct: </p>
# The methods or classes are not correctly defined.

# %%
a = 3
# %check e3
# Out:
# <p style="color:red;">There are issues with the provided response: </p>
# The value of 'a' is not correct respect to the answer
#
# The value of 'a' is: 3
# Expected: 2

# %%
count = 0
while count < 4:
    print(count)
    count += 1
# %check e4
# Out:
# 0
# 1
# 2
# 3
# We notices that you repeatedly got wrong at certain question, please refer to the following answer and find the difference:
#
#
# for i in range(4):
#     print(i)

# %%
|
